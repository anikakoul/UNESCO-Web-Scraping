# %%
from IPython.lib.security import passwd
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import re
import requests
from urllib.request import Request, urlopen
from urllib.error import URLError, HTTPError
from urllib3.exceptions import InsecureRequestWarning
import numpy as np
from time import sleep
from random import randint

req = Request("https://unevoc.unesco.org/home/Explore+the+UNEVOC+Network/lang=en") # downloads webpage data

html_page = urlopen(req) # downloads webpage data
soup = BeautifulSoup(html_page, "lxml") # loads data into a beautifulsoup object

# links = [] # creates empty list for links
# for link in soup.findAll('a'): # a is indicator for links in html
    # links.append(link.get('href')) # adds links to list

links = ['/home/Explore+the+UNEVOC+Network/lang=en/centre=3036',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=519',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=532',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3030',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=529',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=341',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2504',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=446',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=538',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3048',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=522',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3094',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=342',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=334',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=375',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=1030',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=435',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=410',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=336',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=442',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=511',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3056',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3096',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3063',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3054',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3049',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=493',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=492',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=353',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=518',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2581',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3062',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=366',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3038',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=415',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2985',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3069',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=315',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2599',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=419',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3095',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2603',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=1272',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2602',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3046',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=346',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=544',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=356',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3058',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=477',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=358',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3091',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=494',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=392',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=352',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2723',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=509',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=462',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=302',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=304',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=303',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3097',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=432',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=413',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=512',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2897',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2132',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3059',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=535',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3041',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2533',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3090',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=450',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=536',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=472',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2605',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2759',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3047',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=467',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2615',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=501',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3050',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2694',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3057',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2698',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=408',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2988',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2688',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3075',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=374',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=301',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3080',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=312',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2969',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=376',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3071',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2712',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=322',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2629',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3081',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=428',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3034',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=288',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=337',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=409',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2924',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=505',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=351',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=350',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=458',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=390',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3064',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3073',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3074',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=403',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=452',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=321',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=473',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=508',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=289',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2753',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=396',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=348',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=466',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=448',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=388',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=497',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=479',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=319',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3088',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=347',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=349',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=317',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=333',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=484',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=306',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=412',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3051',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=323',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=471',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3078',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3079',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=527',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=424',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=314',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=294',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3052',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2910',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=1213',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=299',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=488',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=451',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=457',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=287',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2899',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3037',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=318',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=308',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=429',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=371',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2895',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=369',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2896',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=328',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=357',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3040',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2029',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3083',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=382',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=1933',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=469',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2776',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=340',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=389',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3072',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=406',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3087',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3033',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=316',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3042',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=407',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2994',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=330',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=414',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=300',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3066',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=367',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=427',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3084',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=395',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=500',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3043',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3065',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=525',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=449',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=542',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3031',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=298',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2894',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=387',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3085',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=402',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=291',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3053',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=438',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=393',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2913',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=397',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3086',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3070',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=1346',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3039',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=394',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2604',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=400',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3060',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=421',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3068',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=437',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3055',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3098',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=883',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=425',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=3044',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=361',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=516',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=521',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=309',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=380',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=441',
         '/home/Explore+the+UNEVOC+Network/lang=en/centre=2551']

newLinks = []
for link in links:
  conLink = "https://unevoc.unesco.org"
  newLink = conLink + link
  newLinks.append(newLink)

links2 = []

for link in newLinks:
  req = Request(link) # downloads webpage data
  html_page = urlopen(req) # downloads webpage data
  soup = BeautifulSoup(html_page, "lxml") # loads data into a beautifulsoup object

  for link in soup.findAll("b", string = "Website"): # finds website string
    findLink = link.find_next_sibling("a") # finds links after website
    links2.append(findLink.get('href')) # adds links to list

allEmails = []

for link in links2:
  req = Request(link) # downloads webpage data
  try:
    html_page = urlopen(req) # downloads webpage data
    soup = BeautifulSoup(html_page, "lxml") # loads data into a beautifulsoup object

    for link in soup.findAll():
      link = str(link.text) # changes links to strings
      email_pattern = r"[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,4}" # establishes pattern of emails
      emails = re.findall(email_pattern, link) # finds all emails

      if emails != []: # removes null emails
        if len(emails) == 1:
          allEmails.append(emails[0]) # adds only first element of each list to allEmails

  except Exception as e:
    print("There was an error, error = {e}")
    pass

finalList = list(set(allEmails)) # removes duplicate emails
print(finalList)
# Out:
# There was an error, error = {e}
# There was an error, error = {e}
# There was an error, error = {e}
# There was an error, error = {e}
# There was an error, error = {e}
# There was an error, error = {e}
# There was an error, error = {e}
# There was an error, error = {e}
# There was an error, error = {e}
# There was an error, error = {e}
# There was an error, error = {e}
# There was an error, error = {e}
# There was an error, error = {e}
# There was an error, error = {e}
# There was an error, error = {e}
# There was an error, error = {e}
# There was an error, error = {e}
# There was an error, error = {e}
# There was an error, error = {e}
# There was an error, error = {e}
# There was an error, error = {e}
# There was an error, error = {e}
# There was an error, error = {e}
# There was an error, error = {e}
# There was an error, error = {e}
# There was an error, error = {e}
# There was an error, error = {e}
# There was an error, error = {e}
# There was an error, error = {e}
# ...
